# %%
import pandas as pd
import os

train = pd.read_csv('../data/raw/cell2celltrain.csv')
holdout = pd.read_csv('../data/raw/cell2cellholdout.csv')

print("Train shape:", train.shape)
print("Holdout shape:", holdout.shape)
print("\nChurn distribution:")
print(train['Churn'].value_counts())
print("\nFirst 3 columns:", train.columns[:3].tolist())
# Out:
# Train shape: (51047, 58)
# Holdout shape: (20000, 58)
#
# Churn distribution:
# Churn
# No     36336
# Yes    14711
# Name: count, dtype: int64
#
# First 3 columns: ['CustomerID', 'Churn', 'MonthlyRevenue']
